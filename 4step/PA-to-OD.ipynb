# %%
import pandas as pd
import numpy as np

# %%
path = 'C:/Users/User/Desktop/583-chicago/2step/trip_distribution.csv'

# %%
df = pd.read_csv(path, head = "None")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-443aee9f6af9> in <module>
# ----> 1 df = pd.read_csv(path, head = "None")
#
# TypeError: parser_f() got an unexpected keyword argument 'head'

# %%
df
# Out:
#    1.679817144649407268e+07  2.372141180933778287e+03  \
# 0              6.390497e-08              2.925275e+06
# 1              5.235872e-05              4.239520e+05
# 2              1.889260e-11              5.898875e+03
# 3              5.542352e-05              1.718301e+05
# 4              2.090047e-29              2.993501e-23
# 5              4.226351e-21              6.096230e-10
# 6              8.337767e-01              4.572465e+05
# 7              3.444029e+04              4.897989e+05
# 8              1.351959e+05              7.310034e+00
# 9              8.586853e+05              5.562352e-07
#
#    4.876778977225772086e-27  3.302066826804680556e-16  \
# 0              5.971546e-29              7.254043e-12
# 1              3.481939e+05              4.053964e-08
# 2              6.807594e-28              1.504778e+06
# 3              1.690722e-03              6.335954e-04
# 4              7.425283e-56              3.478212e-34
# ...
